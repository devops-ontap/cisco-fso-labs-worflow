# %%
#!/usr/bin/env python
import json, re, sys, os, json, subprocess, time, logging, requests, urllib3
from subprocess import call, check_output
from requests.structures import CaseInsensitiveDict
urllib3.disable_warnings()
#token = os.getenv('TE_OATHTOKEN')
token = '1d0acd78-a470-44ad-a6d6-0892ac2db441'
print("printing token")
print(token)
url = "https://api.thousandeyes.com/v6/tests.json"
payload={}
headers = {'Authorization': 'Bearer ' + token}
agent_response = requests.request("GET", url, headers=headers, data=payload)
print(agent_response)
# Out:
# printing token
# 1d0acd78-a470-44ad-a6d6-0892ac2db441
# <Response [200]>

# %%
test_list_json = agent_response.json()
print(test_list_json)
# Out:
# {'test': [{'createdDate': '2022-03-16 20:50:59', 'modifiedDate': '2022-03-18 19:47:58', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'modifiedBy': 'Sherri Conrod (sconrod@cisco.com)', 'enabled': 0, 'savedEvent': 0, 'testId': 2637115, 'testName': 'agent_to_server', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protocol': 'TCP', 'ipv6Policy': 'USE_AGENT_POLICY', 'networkMeasurements': 1, 'mtuMeasurements': 1, 'bandwidthMeasurements': 0, 'bgpMeasurements': 0, 'usePublicBgp': 0, 'dscpId': 0, 'alertsEnabled': 0, 'liveShare': 0, 'pingPayloadSize': -1, 'probeMode': 'AUTO', 'continuousMode': 0, 'pathTraceMode': 'classic', 'numPathTraces': 3, 'apiLinks': [{'rel': 'self', 'href': 'https://api.thousandeyes.com/v6/tests/2637115'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/metrics/2637115'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/path-vis/2637115'}], 'dscp': 'Best Effort (DSCP 0)'}, {'createdDate': '2022-07-19 16:06:31', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'enabled': 1, 'savedEvent': 0, 'testId': 3000485, 'testName': 'anastasiya-test', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protocol': 'TCP', 'ipv6Policy': 'USE_AGENT_POLICY', 'networkMeasurements': 1, 'mtuMeasurements': 1, 'bandwidthMeasurements': 0, 'bgpMeasurements': 0, 'usePublicBgp': 0, 'dscpId': 0, 'alertsEnabled': 0, 'liveShare': 0, 'pingPayloadSize': -1, 'probeMode': 'AUTO', 'continuousMode': 0, 'pathTraceMode': 'classic', 'numPathTraces': 3, 'apiLinks': [{'rel': 'self', 'href': 'https://api.thousandeyes.com/v6/tests/3000485'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/metrics/3000485'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/path-vis/3000485'}], 'dscp': 'Best Effort (DSCP 0)'}, {'createdDate': '2022-07-19 15:56:34', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'enabled': 1, 'savedEvent': 0, 'testId': 3000468, 'testName': 'anuj-test', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protocol': 'TCP', 'ipv6Policy': 'USE_AGENT_POLICY', 'networkMeasurements': 1, 'mtuMeasurements': 1, 'bandwidthMeasurements': 0, 'bgpMeasurements': 0, 'usePublicBgp': 0, 'dscpId': 0, 'alertsEnabled': 0, 'liveShare': 0, 'pingPayloadSize': -1, 'probeMode': 'AUTO', 'continuousMode': 0, 'pathTraceMode': 'classic', 'numPathTraces': 3, 'apiLinks': [{'rel': 'self', 'href': 'https://api.thousandeyes.com/v6/tests/3000468'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/metrics/3000468'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/path-vis/3000468'}], 'dscp': 'Best Effort (DSCP 0)'}, {'createdDate': '2022-07-18 16:37:56', 'modifiedDate': '2022-07-18 17:40:51', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'modifiedBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'enabled': 1, 'savedEvent': 0, 'testId': 2998698, 'testName': 'Hailu_Meng', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protocol': 'TCP', 'ipv6Policy': 'USE_AGENT_POLICY', 'networkMeasurements': 1, 'mtuMeasurements': 1, 'bandwidthMeasurements': 1, 'bgpMeasurements': 0, 'usePublicBgp': 0, 'dscpId': 0, 'alertsEnabled': 0, 'liveShare': 0, 'pingPayloadSize': -1, 'probeMode': 'AUTO', 'continuousMode': 0, 'pathTraceMode': 'classic', 'numPathTraces': 3, 'apiLinks': [{'rel': 'self', 'href': 'https://api.thousandeyes.com/v6/tests/2998698'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/metrics/2998698'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/path-vis/2998698'}], 'dscp': 'Best Effort (DSCP 0)'}, {'createdDate': '2022-07-18 16:06:05', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'enabled': 1, 'savedEvent': 0, 'testId': 2998655, 'testName': 'haimeng', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', ...

# %%
test_list = test_list_json['test']
print(type(test_list))
print(test_list)
# Out:
# <class 'list'>
# [{'createdDate': '2022-03-16 20:50:59', 'modifiedDate': '2022-03-18 19:47:58', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'modifiedBy': 'Sherri Conrod (sconrod@cisco.com)', 'enabled': 0, 'savedEvent': 0, 'testId': 2637115, 'testName': 'agent_to_server', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protocol': 'TCP', 'ipv6Policy': 'USE_AGENT_POLICY', 'networkMeasurements': 1, 'mtuMeasurements': 1, 'bandwidthMeasurements': 0, 'bgpMeasurements': 0, 'usePublicBgp': 0, 'dscpId': 0, 'alertsEnabled': 0, 'liveShare': 0, 'pingPayloadSize': -1, 'probeMode': 'AUTO', 'continuousMode': 0, 'pathTraceMode': 'classic', 'numPathTraces': 3, 'apiLinks': [{'rel': 'self', 'href': 'https://api.thousandeyes.com/v6/tests/2637115'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/metrics/2637115'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/path-vis/2637115'}], 'dscp': 'Best Effort (DSCP 0)'}, {'createdDate': '2022-07-19 16:06:31', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'enabled': 1, 'savedEvent': 0, 'testId': 3000485, 'testName': 'anastasiya-test', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protocol': 'TCP', 'ipv6Policy': 'USE_AGENT_POLICY', 'networkMeasurements': 1, 'mtuMeasurements': 1, 'bandwidthMeasurements': 0, 'bgpMeasurements': 0, 'usePublicBgp': 0, 'dscpId': 0, 'alertsEnabled': 0, 'liveShare': 0, 'pingPayloadSize': -1, 'probeMode': 'AUTO', 'continuousMode': 0, 'pathTraceMode': 'classic', 'numPathTraces': 3, 'apiLinks': [{'rel': 'self', 'href': 'https://api.thousandeyes.com/v6/tests/3000485'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/metrics/3000485'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/path-vis/3000485'}], 'dscp': 'Best Effort (DSCP 0)'}, {'createdDate': '2022-07-19 15:56:34', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'enabled': 1, 'savedEvent': 0, 'testId': 3000468, 'testName': 'anuj-test', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protocol': 'TCP', 'ipv6Policy': 'USE_AGENT_POLICY', 'networkMeasurements': 1, 'mtuMeasurements': 1, 'bandwidthMeasurements': 0, 'bgpMeasurements': 0, 'usePublicBgp': 0, 'dscpId': 0, 'alertsEnabled': 0, 'liveShare': 0, 'pingPayloadSize': -1, 'probeMode': 'AUTO', 'continuousMode': 0, 'pathTraceMode': 'classic', 'numPathTraces': 3, 'apiLinks': [{'rel': 'self', 'href': 'https://api.thousandeyes.com/v6/tests/3000468'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/metrics/3000468'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/path-vis/3000468'}], 'dscp': 'Best Effort (DSCP 0)'}, {'createdDate': '2022-07-18 16:37:56', 'modifiedDate': '2022-07-18 17:40:51', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'modifiedBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'enabled': 1, 'savedEvent': 0, 'testId': 2998698, 'testName': 'Hailu_Meng', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protocol': 'TCP', 'ipv6Policy': 'USE_AGENT_POLICY', 'networkMeasurements': 1, 'mtuMeasurements': 1, 'bandwidthMeasurements': 1, 'bgpMeasurements': 0, 'usePublicBgp': 0, 'dscpId': 0, 'alertsEnabled': 0, 'liveShare': 0, 'pingPayloadSize': -1, 'probeMode': 'AUTO', 'continuousMode': 0, 'pathTraceMode': 'classic', 'numPathTraces': 3, 'apiLinks': [{'rel': 'self', 'href': 'https://api.thousandeyes.com/v6/tests/2998698'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/metrics/2998698'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/path-vis/2998698'}], 'dscp': 'Best Effort (DSCP 0)'}, {'createdDate': '2022-07-18 16:06:05', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'enabled': 1, 'savedEvent': 0, 'testId': 2998655, 'testName': 'haimeng', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protoco ...

# %%
list_of_dictionaries = test_list
sought_value = "agent-to-server"
found_values = []
for dictionary in list_of_dictionaries:
    if (dictionary["type"] == "agent-to-server"):
        found_values.append(dictionary)
print(found_values)
# Out:
# [{'createdDate': '2022-03-16 20:50:59', 'modifiedDate': '2022-03-18 19:47:58', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'modifiedBy': 'Sherri Conrod (sconrod@cisco.com)', 'enabled': 0, 'savedEvent': 0, 'testId': 2637115, 'testName': 'agent_to_server', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protocol': 'TCP', 'ipv6Policy': 'USE_AGENT_POLICY', 'networkMeasurements': 1, 'mtuMeasurements': 1, 'bandwidthMeasurements': 0, 'bgpMeasurements': 0, 'usePublicBgp': 0, 'dscpId': 0, 'alertsEnabled': 0, 'liveShare': 0, 'pingPayloadSize': -1, 'probeMode': 'AUTO', 'continuousMode': 0, 'pathTraceMode': 'classic', 'numPathTraces': 3, 'apiLinks': [{'rel': 'self', 'href': 'https://api.thousandeyes.com/v6/tests/2637115'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/metrics/2637115'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/path-vis/2637115'}], 'dscp': 'Best Effort (DSCP 0)'}, {'createdDate': '2022-07-19 16:06:31', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'enabled': 1, 'savedEvent': 0, 'testId': 3000485, 'testName': 'anastasiya-test', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protocol': 'TCP', 'ipv6Policy': 'USE_AGENT_POLICY', 'networkMeasurements': 1, 'mtuMeasurements': 1, 'bandwidthMeasurements': 0, 'bgpMeasurements': 0, 'usePublicBgp': 0, 'dscpId': 0, 'alertsEnabled': 0, 'liveShare': 0, 'pingPayloadSize': -1, 'probeMode': 'AUTO', 'continuousMode': 0, 'pathTraceMode': 'classic', 'numPathTraces': 3, 'apiLinks': [{'rel': 'self', 'href': 'https://api.thousandeyes.com/v6/tests/3000485'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/metrics/3000485'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/path-vis/3000485'}], 'dscp': 'Best Effort (DSCP 0)'}, {'createdDate': '2022-07-19 15:56:34', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'enabled': 1, 'savedEvent': 0, 'testId': 3000468, 'testName': 'anuj-test', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protocol': 'TCP', 'ipv6Policy': 'USE_AGENT_POLICY', 'networkMeasurements': 1, 'mtuMeasurements': 1, 'bandwidthMeasurements': 0, 'bgpMeasurements': 0, 'usePublicBgp': 0, 'dscpId': 0, 'alertsEnabled': 0, 'liveShare': 0, 'pingPayloadSize': -1, 'probeMode': 'AUTO', 'continuousMode': 0, 'pathTraceMode': 'classic', 'numPathTraces': 3, 'apiLinks': [{'rel': 'self', 'href': 'https://api.thousandeyes.com/v6/tests/3000468'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/metrics/3000468'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/path-vis/3000468'}], 'dscp': 'Best Effort (DSCP 0)'}, {'createdDate': '2022-07-18 16:37:56', 'modifiedDate': '2022-07-18 17:40:51', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'modifiedBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'enabled': 1, 'savedEvent': 0, 'testId': 2998698, 'testName': 'Hailu_Meng', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protocol': 'TCP', 'ipv6Policy': 'USE_AGENT_POLICY', 'networkMeasurements': 1, 'mtuMeasurements': 1, 'bandwidthMeasurements': 1, 'bgpMeasurements': 0, 'usePublicBgp': 0, 'dscpId': 0, 'alertsEnabled': 0, 'liveShare': 0, 'pingPayloadSize': -1, 'probeMode': 'AUTO', 'continuousMode': 0, 'pathTraceMode': 'classic', 'numPathTraces': 3, 'apiLinks': [{'rel': 'self', 'href': 'https://api.thousandeyes.com/v6/tests/2998698'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/metrics/2998698'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/path-vis/2998698'}], 'dscp': 'Best Effort (DSCP 0)'}, {'createdDate': '2022-07-18 16:06:05', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'enabled': 1, 'savedEvent': 0, 'testId': 2998655, 'testName': 'haimeng', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protoco ...

# %%
test_list = test_list_json['test']
list_of_dictionaries = test_list
sought_value = "testName"
found_values = []
for dictionary in list_of_dictionaries:
    if (dictionary["testName"] == "sconrod-test"):
        found_values.append(dictionary)
print(found_values)
empty_list=[]
for item in found_values:
    testId=item['testId']
    print(testId)
# Out:
# [{'createdDate': '2022-07-17 22:00:41', 'modifiedDate': '2022-07-19 15:40:21', 'createdBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'modifiedBy': 'fsolab4@gmail.com (fsolab4@gmail.com)', 'enabled': 1, 'savedEvent': 0, 'testId': 2994789, 'testName': 'sconrod-test', 'type': 'agent-to-server', 'interval': 300, 'subinterval': -1, 'server': 'www.thousandeyes.com:80', 'protocol': 'TCP', 'ipv6Policy': 'USE_AGENT_POLICY', 'networkMeasurements': 1, 'mtuMeasurements': 1, 'bandwidthMeasurements': 0, 'bgpMeasurements': 0, 'usePublicBgp': 0, 'dscpId': 0, 'alertsEnabled': 0, 'liveShare': 0, 'pingPayloadSize': -1, 'probeMode': 'AUTO', 'continuousMode': 0, 'pathTraceMode': 'classic', 'numPathTraces': 3, 'apiLinks': [{'rel': 'self', 'href': 'https://api.thousandeyes.com/v6/tests/2994789'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/metrics/2994789'}, {'rel': 'data', 'href': 'https://api.thousandeyes.com/v6/net/path-vis/2994789'}], 'dscp': 'Best Effort (DSCP 0)'}]
# 2994789

# %%
#tests/agent-to-server/2994789/update.json
url='https://api.thousandeyes.com/v6/tests/agent-to-server/2994789/update.json'
payload = {'bgpMeasurements': '1'}
header = {'content-type': 'application/json', 'authorization': 'Bearer ' + token}
r = requests.post(url, data=json.dumps(payload), headers=header, verify=False)
print(r)
# Out:
# <Response [400]>
